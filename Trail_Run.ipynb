# %%
from spectral_data_types.Channel import Channel
from spectral_data_types.Particle import Particle
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\envs\datascience\Lib\site-packages\IPython\core\interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 2
#     from spectral_data_types.Particle import Particle
#
#   File ~\OneDrive\Documents\PythonScripts\DS2\Spectrals_Project\spectral_data_types\__init__.py:2
#     from .Particle import Particle
#
#   File ~\OneDrive\Documents\PythonScripts\DS2\Spectrals_Project\spectral_data_types\Particle.py:227
#     current_channel_midpoints, chan1_midpoins =  [tuple[0], tuple[1] for tuple in aligment_peaks]
#                                                   ^
# SyntaxError: did you forget parentheses around the comprehension target?
