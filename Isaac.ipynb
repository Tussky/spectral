# %% [markdown]
# ### Imports

# %%
# non-native
import pandas as pd 
import numpy as np 
from scipy.signal import find_peaks

# local
import channel
from utils.plotting import plot_spectra_on_histogram
from utils.misc import read_in_hdf5_spectra

# %%
spectra_df = read_in_hdf5_spectra()
display(spectra_df)
# Out:
#                                                     energy
# chan1    [1917.8376, 2934.2834, 1235.1354, 8561.532, 37...
# chan101  [9945.653, 11679.518, 8148.7476, 8897.93, 1198...
# chan103  [11883.796, 10292.644, 4876.378, 7284.5176, 14...
# chan105  [16857.314, 13127.779, 7157.272, 8648.918, 109...
# chan107  [8264.235, 12281.665, 9715.321, 4386.601, 9545...
# ...                                                    ...
# chan91   [8327.866, 10658.192, 9713.913, 11110.397, 111...
# chan93   [9339.398, 5042.0146, 13543.274, 771.2593, 898...
# chan95   [1961.5458, 10050.026, 5540.5645, 8491.4, 1023...
# chan97   [8372.382, 12644.367, 9724.269, 3330.2563, 913...
# chan99   [157.17722, 1.1189944, 10993.551, 5599.347, 61...
#
# [116 rows x 1 columns]

# %%
channel_obj = channel.channel(spectra_df.loc['chan1'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 channel_obj = channel.channel(spectra_df.loc['chan1'])
#
# File ~/schoolspace/DataScienceII/Spectral/channel.py:16, in channel.__init__(self, energies)
#      13 def __init__(self, energies: pd.Series):
#      14    assert len(energies.shape) == 1, "energy needs to be a one dimensional pd.Series"
# ---> 16    self.energy = energies[(0 < energies) & (energies < np.percentile(energies, 97))]
#      17    self.edges, self.counts = np.histogram(self.energy, 10_000)
#      18    self.midpoints = 0.5 * (self.edges[1:] + self.edges[:1])
#
# File ~/schoolspace/DataScienceII/Spectral/.venv/lib64/python3.13/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ...
