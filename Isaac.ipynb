# %% [markdown]
# ### Imports

# %%
# non-native
import pandas as pd 
import numpy as np 
import plotly.express as px
import nbformat # requirement for plotly
from scipy.signal import find_peaks


# local
import channel
from utils.plotting import plot_spectra_on_histogram
from utils.misc import read_in_hdf5_spectra

# dataframes
spectra_df = read_in_hdf5_spectra()

# %%
channel_obj = channel.channel(spectra_df.loc['chan1'])

# %%
px.line(
    x = channel_obj.midpoints,
    y = channel_obj.counts
)

# %%
plot_spectra_on_histogram()
