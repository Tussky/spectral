# %% [markdown]
# ### Imports

# %%
# non-native
import pandas as pd 
import numpy as np 
import plotly.express as px
import nbformat # requirement for plotly
from scipy.signal import find_peaks


# local
from channel import channel
from particle import particle
from utils.plotting import plot_spectra_on_histogram
from utils.misc import read_in_hdf5_spectra

# dataframes
spectra_df = read_in_hdf5_spectra()
spectra_df.loc['chan1':'chan99']
# Out:
#                                                     energy
# chan1    [1917.8376, 2934.2834, 1235.1354, 8561.532, 37...
# chan101  [9945.653, 11679.518, 8148.7476, 8897.93, 1198...
# chan103  [11883.796, 10292.644, 4876.378, 7284.5176, 14...
# chan105  [16857.314, 13127.779, 7157.272, 8648.918, 109...
# chan107  [8264.235, 12281.665, 9715.321, 4386.601, 9545...
# ...                                                    ...
# chan91   [8327.866, 10658.192, 9713.913, 11110.397, 111...
# chan93   [9339.398, 5042.0146, 13543.274, 771.2593, 898...
# chan95   [1961.5458, 10050.026, 5540.5645, 8491.4, 1023...
# chan97   [8372.382, 12644.367, 9724.269, 3330.2563, 913...
# chan99   [157.17722, 1.1189944, 10993.551, 5599.347, 61...
#
# [116 rows x 1 columns]

# %%
particle(spectral_dataframe=spectra_df.loc['chan1':'chan91'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 particle(spectral_dataframe=spectra_df.loc['chan1':'chan91'])
#
# File ~/schoolspace/DataScienceII/Spectral/particle.py:20, in particle.__init__(self, spectral_dataframe)
#      15 """Initialise a particle object with a pd.DataFrame.
#      16 Params:
#      17     spectra_dataframe (pd.DataFrame) : A dataframe with loc 'channel name' and one column with the energies
#      18 """
#      19 for name, energies in spectral_dataframe.iterrows():
# ---> 20     self.channels[name] = channel(energies)
#
# AttributeError: 'particle' object has no attribute 'channels'

# %%
print(vars(particle))
# Out:
# {'__module__': 'particle', '__firstlineno__': 3, '__annotations__': {'channels': dict[channel.channel], 'peak_indices': list[pandas.core.series.Series], 'summed_channels': <class 'pandas.core.series.Series'>}, '__init__': <function particle.__init__ at 0x7f85b6f96de0>, '__iter__': <function particle.__iter__ at 0x7f85b6f96d40>, '__len__': <function particle.__len__ at 0x7f85b6f96e80>, '__getitem__': <function particle.__getitem__ at 0x7f85b6f96f20>, 'sum_channels': <function particle.sum_channels at 0x7f85b6f96fc0>, 'plot_particle': <function particle.plot_particle at 0x7f85b6f97060>, '__static_attributes__': ('channels', 'summed_channels'), '__dict__': <attribute '__dict__' of 'particle' objects>, '__weakref__': <attribute '__weakref__' of 'particle' objects>, '__doc__': None}
